# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 1001)

p1 = stats.lognorm.pdf(x, 1)
c1 = stats.lognorm.cdf(x, 1)

p2 = stats.lognorm.pdf(x, 0.1)
c2 = stats.lognorm.cdf(x, 0.1)

# %%
p1
# Out:
# array([0.00000000e+00, 6.39950626e-05, 9.90238665e-04, ...,
#        2.19651199e-02, 2.19078250e-02, 2.18507148e-02])

# %%
c1
# Out:
# array([0.00000000e+00, 5.84373485e-08, 2.06064340e-06, ...,
#        9.46020611e-01, 9.46130293e-01, 9.46239690e-01])

# %%
p2
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#        6.24044036e-57, 5.30693267e-57, 4.51334809e-57])

# %%
c2
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
fig, ax = plt.subplots(2, 1, figsize = (16, 8))

ax[0].plot(x, p1)
ax[0].plot(x, p2)
ax[0].set_xlabel('PDF')
ax[0].set_ylabel('Probability')

ax[1].plot(x, c1)
ax[1].plot(x, c2)
ax[1].set_xlabel('CDF')
ax[1].set_ylabel('Probability')

plt.show()

# %%
c1x = np.cumsum(p1 * (x[1] - x[0]))

plt.figure(figsize = (12, 8))
plt.plot(x, c1, linewidth = 2)
plt.plot(x, c1x, '--', linewidth = 2)
plt.show()
